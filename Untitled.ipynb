# %%
import pandas as pd

# %%
file = 'tabn208.30.csv'

data = pd.read_csv(file)
data
# Out:
#                                 State or jurisdiction  Fall 2000 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                                                   1          2        NaN
# 2                       United States ...............  2,941,461        \1\
# 3                  Alabama ..........................     48,194        \2\
# 4                    Alaska .........................      7,880        NaN
# ..                                                ...        ...        ...
# 81  \6\Includes imputations to correct for underre...        NaN        NaN
# 82  NOTE: Distribution of elementary and secondary...        NaN        NaN
# 83  SOURCE: U.S. Department of Education, National...        NaN        NaN
# 84                                                           NaN        NaN
# 85                                                NaN        NaN        NaN
#
# ...

# %%
data.columns
# Out:
# Index(['Table 208.40. Public elementary and secondary teachers, enrollment, and pupil/teacher ratios, by state or jurisdiction: Selected years, fall 2000 \n              through fall 2014',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-2c19414f7414> in <module>
# ----> 1 data.set_index[0]
#
# TypeError: 'method' object is not subscriptable
