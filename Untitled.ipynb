# %%
import pandas as pd

# %%
file = 'tabn208.30.xls'

data = pd.read_excel(file)
data
# Out:
#    Table 208.30. Public elementary and secondary teachers, by level and state or jurisdiction: Selected years, fall 2000 through fall 2014  \
# 0                          [In full-time equivalents]
# 1                               State or jurisdiction
# 2                                                 NaN
# 3                                                   1
# 4                       United States ...............
# ..                                                ...
# 82  \5\Includes imputations to correct for underre...
# 83  \6\Includes imputations to correct for underre...
# 84  NOTE: Distribution of elementary and secondary...
# 85  SOURCE: U.S. Department of Education, National...
# 86
#
#      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4   Unnamed: 5 Unnamed: 6  \
# 0           NaN        NaN        NaN        NaN          NaN        NaN
# 1     Fall 2000        NaN  Fall 2005        NaN    Fall 2010        NaN
# ...

# %%
data.columns
# Out:
# Index(['Table 208.40. Public elementary and secondary teachers, enrollment, and pupil/teacher ratios, by state or jurisdiction: Selected years, fall 2000 \n              through fall 2014',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-2c19414f7414> in <module>
# ----> 1 data.set_index[0]
#
# TypeError: 'method' object is not subscriptable
