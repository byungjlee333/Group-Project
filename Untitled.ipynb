# %%
import pandas as pd

# %%
file = 'Final Data Ratio.csv'

data = pd.read_csv(file)
data
# Out:
#       State/Jurisdiction  Fall 2000  Fall 2009  Fall 2010  Fall 2011  \
# 0          United States       16.0       15.4       16.0       16.0
# 1                Alabama       15.4       15.8       15.3       15.6
# 2                 Alaska       16.9       16.3       16.2       16.2
# 3                Arizona       19.8       20.7       21.4       21.3
# 4               Arkansas       14.1       12.9       14.1       14.2
# 5             California       20.6       19.8       24.1       23.4
# 6               Colorado       17.3       17.0       17.4       17.8
# 7            Connecticut       13.7       12.9       13.1       12.7
# 8               Delaware       15.4       14.7       14.5       15.0
# 9   District of Columbia       13.9       11.9       12.0       11.8
# 10               Florida       18.4       14.3       15.1       15.2
# 11               Georgia       15.9       14.4       14.9       15.2
# 12                Hawaii       16.9       15.7       15.8       15.9
# ...
